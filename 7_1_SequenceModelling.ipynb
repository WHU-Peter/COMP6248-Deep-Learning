# %% [markdown]
# <a href="https://colab.research.google.com/github/WHU-Peter/COMP6248-Deep-Learning/blob/master/7_1_SequenceModelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1: Sequence Modelling

# %% [markdown]
# __Before starting, we recommend you enable GPU acceleration if you're running on Colab.__

# %%
# Execute this code block to install dependencies when running on colab
try:
    import torch
except:
    from os.path import exists
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
    accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.0.0-{platform}-linux_x86_64.whl torchvision

try: 
    import torchbearer
except:
    # !pip install torchbearer

import torch
import torchbearer
from torchvision.datasets.utils import download_url
import random
import sys
import io

# %% [markdown]
# ## Markov chains
#
# We'll start our exploration of modelling sequences and building generative models using a 1st order Markov chain. The Markov chain is a stochastic model describing a sequence of possible events in which the probability of each event depends only on the state attained in the previous event. In our case we're going to learn a model over a set of characters from an English language text. The events, or states, in our model are the set of possible characters, and we'll learn the probability of moving from one character to the next.
#
# Let's start by loading the data from the web:

# %%
# Read the data
download_url('https://s3.amazonaws.com/text-datasets/nietzsche.txt', '.', 'nietzsche.txt', None)
text = io.open('./nietzsche.txt', encoding='utf-8').read().lower()
print('corpus length:', len(text))
# Out:
# Using downloaded and verified file: ./nietzsche.txt
# corpus length: 600893

# %% [markdown]
# We now need to iterate over the characters in the text and count the times each transition happens:

# %%
transition_counts = dict()
for i in range(0,len(text)-1):
    currc = text[i]
    nextc = text[i+1]
    if currc not in transition_counts:
        transition_counts[currc] = dict()
    if nextc not in transition_counts[currc]:
        transition_counts[currc][nextc] = 0
    transition_counts[currc][nextc] += 1

# %% [markdown]
# The `transition_counts` dictionary maps the current character to the next character, and this is then mapped to a count. We can for example use this datastructure to get the number of times the letter 'a' was followed by a 'b':

# %%
print("Number of transitions from 'a' to 'b': " + str(transition_counts['a']['b']))
# Out:
# Number of transitions from 'a' to 'b': 813

# %% [markdown]
# Finally, to complete the model we need to normalise the counts for each initial character into a probability distribution over the possible next character. We'll slightly modify the form we're storing these and maintain a tuple of array objects for each initial character: the first holding the set of possible characters, and the second holding the corresponding probabilities:

# %%
transition_probabilities = dict()
for currentc, next_counts in transition_counts.items():
    values = []
    probabilities = []
    sumall = 0
    for nextc, count in next_counts.items():
        values.append(nextc)
        probabilities.append(count)
        sumall += count
    for i in range(0, len(probabilities)):
        probabilities[i] /= float(sumall)
    transition_probabilities[currentc] = (values, probabilities)

# %% [markdown]
# At this point, we could print out the probability distribution for a given initial character state. For example, to print the distribution for 'a':

# %%
for a,b in zip(transition_probabilities['a'][0], transition_probabilities['a'][1]):
    print(a,b)
# Out:
# c 0.03685183172083922
# t 0.14721708881400153
#   0.05296771388194369
# n 0.2322806826829003
# l 0.11552886183280792
# r 0.08794434177628004
# s 0.0968583541689314
# v 0.0192412218719426
# i 0.03402543754755952
# d 0.026986628981411024
# g 0.017202956843135123
# y 0.02505707142080661
# k 0.012827481247961734
# b 0.02209479291227307
# p 0.020545711490379388
# m 0.02030111968692249
# u 0.011414284161321883
# f 0.004429829329274921
# w 0.004837482335036417
# , 0.0010870746820306554
#
#  0.005353842809000978
# z 0.0006522448092183933
# x 0.0007609522774214588
# o 0.0005435373410153277
# . 0.000489183606913795
# - 0.0004348298728122622
# ' 5.4353734101532776e-05
# j 0.0004348298728122622
# h 0.00035329927165996303
# e 0.0007337754103706925
# : 5.4353734101532776e-05
# a 5.4353734101532776e-05
# ) 0.00010870746820306555
# ! 2.7176867050766388e-05
# ; 2.7176867050766388e-05
# " 8.153060115229916e-05
# q 2.7176867050766388e-05
# _ 8.153060115229916e-05
# [ 2.7176867050766388e-05

# %% [markdown]
# It looks like the most probable letter to follow an 'a' is 'n'.
#
# __What is the most likely letter to follow the letter 'j'? Write your answer in the block below:__

# %%
print(transition_probabilities['j'])
# Out:
# (['e', 'o', 'u', 'a', 'i'], [0.2585278276481149, 0.15080789946140036, 0.5709156193895871, 0.017953321364452424, 0.0017953321364452424])

# %% [markdown]
# We mentioned earlier that the Markov model is generative. This means that we can draw samples from the distributions and iteratively move between states.
#
# Use the following code block to iteratively sample 1000 characters from the model, starting with an initial character 't'. You can use the `torch.multinomial` function to draw a sample from a multinomial distribution (represented by the index) which you can then use to select the next character.

# %%
current = 't'
for i in range(0, 1000):
    print(current, end='')
    # sample the next character based on `current` and store the result in `current`
    probabilities = torch.tensor(transition_probabilities[current][1])
    index = torch.multinomial(probabilities, 1)
    current = transition_probabilities[current][0][index]
# Out:
# t tolt; y, "t il o, he t blwedor w f st por pofenge o knk t hepucimpal, alt theatondicon blof falinsexanth lecere blishithongnd cal panomonk tsan ole th pheredod ns le tofrofymave quiny t the owhatis ans, nth her s seedif orell hinninabe, orty,  sell hithathemaphugennoube inceart to whare'eco pral hised ons hout lavouse
# ind acore mscan atothasiound, s m cifenf, ll, anthallwacevint wein wofoene. ow?"----burth t
# "interbonived thinianenow, dind s dis galutecrat t
# c tllionerdeme (ff s ogelf ber, is ta o
#
# isaty owo n ad tof th alon irer lesicce fooesonty
# 1946. fas, "
# alit o silee. teprexpoidefestandie teralen ostin houalowiss heon bonthe s, ounctalupe d thandrod tir her-or ry s inst, t ffouro me ise ants.
# "m sando po we conssor
# ccamin l frathanlindst of wern pemesither f veliouencingrsheisluliee ig whithoreir
# spur
# akizicoe ogons t
# s
# rpacoy
# ther
#
# the, t apumpothbe imar eray,
# ig ho ang--n  po iouleis anteike,
# tut when fay
# ithexphe t th t th calle
# inest witofes toream buly honanormenve ssste t

# %% [markdown]
# You should observe a result that is clearly not English, but it should be obvious that some of the common structures in the English language have been captured.
#
# __Rather than building a model based on individual characters, can you implement a model in the following code block that works on words instead?__

# %%
text_split = text.split(" ")
transition_counts = dict()
for i in range(0,len(text_split)-1):
    currc = text_split[i]
    nextc = text_split[i+1]
    if currc not in transition_counts:
        transition_counts[currc] = dict()
    if nextc not in transition_counts[currc]:
        transition_counts[currc][nextc] = 0
    transition_counts[currc][nextc] += 1

transition_probabilities = dict()
for currentc, next_counts in transition_counts.items():
    values = []
    probabilities = []
    sumall = 0
    for nextc, count in next_counts.items():
        values.append(nextc)
        probabilities.append(count)
        sumall += count
    for i in range(0, len(probabilities)):
        probabilities[i] /= float(sumall)
    transition_probabilities[currentc] = (values, probabilities)

current = 'a'
for i in range(0, 1000):
    print(current, end=' ')
    # sample the next character based on `current` and store the result in `current`
    probabilities = torch.tensor(transition_probabilities[current][1])
    index = torch.multinomial(probabilities, 1)
    current = transition_probabilities[current][0][index]
# Out:
# a type man goes about these artists if possible effort," and less great. to the influence which the canon of forbearance a homesickness for its old
# corner.--one ought to be born rat-catcher of letting gifts to say, a few, perhaps such thenceforward. hence
# every society other man thinks well to feel a very peaceful conditions of cases of
# wise old testament for the nature
# man knows itself in which the
# french can be delusive--but in germany,
# however (until quite immaterial; in relation to interpret himself when the dreamer will or a violation of world of
# phenomena--that is, in the realm of suicide of life, are overcome metaphysics. later, when one must remove hence he who performed the jesuitism of
# mediocrity, which power and diseased
# in his church). in the
# same time begins to propound some miracle were morality do no one had to see if they were morality is really at any redeeming intention as the stoics advised and
# fostered; or touch
# of allurement, to us it all these little bundle of seemingness, and there honoured--he would not that anybody does it does not
# exist, he wishes to
# bite, hiss, and the
# capacity of enlightenment, the
# demands of exercising volition adds warningly:
# "he who in inversion, nor bad. in the reverence which had a thing necessary in the confession of harmlessness of self mastery, indefatigable industry and refined
# luxuriousness in whom the latter must open his making and comes to many hidden and loftiness and imperious--all instincts and unconscious antagonism to renounce or seven great
# men.--yes, and sun of theorising has scholarly impulses to contemplation and extinguishing appliance we
# can find proof thereof, is a bosom that though he has,
# therefore, grown utilitarian, who are the grisly veil was the case into his
# own brief life at all the spirit generally, one in the introduction of the deed ourselves. perhaps be influenced, hair, finger nails, food means, to let us go back to keep at
# least a plenitude of their simulations, or with a heart
# transformed into consideration in which is something quite other systems in the belief in which has at bottom something
# different and revolution-ideologues, and a sensitive, and bad and which did he dreads the good reasons, it is also the vowels and ethics and averse to how much absorbed in his interlocutor,
# contradictorily--"strong! strong! strong and patchiness of religious element in respect to support them
# with good are "gay men" who no satisfaction of how far off a good europeans!
#
# 244. there not a logical violation of the whole music of human ill.
#
#
# 109
#
# =sorrow is not understand
# what our existence
# are involved, or of contempt for christian virtue of the temperament remained at present on a joy devilish, as
# schopenhauer says? in christianity.=--the greeks did not to convince themselves bind these troubled spirits
# collapse in motion, although, at in
# the so-called moral feelings
# and which, climatically and
# hereditarily, united with
# one another, or
# will afford shade to the
# felicity and just the joke of their co-relation within us. not believe it
# of me: i must dominate it. he knows that
# he wanted to believe, the sole party makes
# the other peoples and thoroughly;--the genius of the
# preservation of humanity: and turn of
# expression; for beethoven! for this
# diagnosis of mankind, manifests
# itself most disturb the same imperative duty to teach their development of gratification in order that it otherwise--and to the danger
# that, through the fathers deemed it
# right to appear too little art and the dream, mankind, or the
# higher morality defends itself surprisingly
# when it against german spirit, it would fain treat each other organs of honour--schopenhauer represents an
# attack on the
# other hand, gait, face, changed? and historic training of it danced round them.
#
# 127. in sin, as little ironical towards themselves although the brightest moments of impressions and capacity
# for prolonged revenge--both only a stigma out of unholiness simply as if it will
# flee from a cause. accordingly, nothing
# could be ignorant; his tendency of which goethe's verse speaks:
#
#           oh, withered words, but also separates.--the
# pity of truth, a despairing,
# mortally wearied soul, notwithstanding the averseness of
# every distinguished and what is only themselves either good and questionable questions! it cannot be of his
# day. hitherto operated upon the other ages
# may envy of the authorities prescribed. but that truth that
# "disinterested" action or
# affair. supposing that you had"--enough, the world, and concealed
# insatiability, as he shall be that he feels no eye and stupidity to devilish, bad. manifestations of religion, with purely
# objectively. but be honoured as hard[ness] the work has
# just made the earth, i am i see if i love of it demands on the space around all modern men, and finally almost a haughtiness of the other growing ever further than the traditional error and the goal.
# something that in china tie cords seem so far too bad! always does he has allowed to every party.--a shepherd has got
# the mastery over one's actions which
# establish his jews: "the problem of pain (sympathy) that it
# is a pivot that is,
# as error) is
# rich in the same degree of millenniums of reason: and vivisection, which scents the witness soundly: one might is only
# gregarious utility, as perhaps evil? and in fact, the egoism really the beautiful
# episode of one's
# fellow creatures: it is not triumph to lurk, to give those of
# duty: that anarchy threatens to teach man goes originally we have reached its worth: a torture are honestly meant is
# that, if you had involuntarily
# extended to special, and hence one of life, are too
# comprehensive to which serves the very reason
# many think and more attention from the seeming
# insignificance of the
# paradox, why should part of instinctive hostility to be interesting to a miraculous may sound, the tragedy
# of it signify, what has its maintenance.--to this knowledge is made from the love with which one speaks--"i listened for its object. this into
# deathless verse:
#
#   consiliis animum fatigas?
#        as from them; in the postulates of the olympian gods could
# all of semi-barbarity in such great surprise, intimated to figure of
# the spirit, to pass over still in broad daylight, and
# even in the last great domain
# of means of today, as he who was always unknown to be taken in
# the positive belief that is, in antitheses of this knowledge that is thoroughly understand by a monad,
# as an assertion sounds hard, but why of the naivetes of many a

# %% [markdown]
# ## RNN-based sequence modelling
#
# It is possible to build higher-order Markov models that capture longer-term dependencies in the text and have higher accuracy, however this does tend to become computationally infeasible very quickly. Recurrent Neural Networks offer a much more flexible approach to language modelling.
#
# We'll use the same data as above, and start by creating mappings of characters to numeric indices (and vice-versa):

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 57

# %% [markdown]
# We'll also write some helper functions to encode and decode the data to/from tensors of indices, and an implementation of a `torch.Dataset` that will return partially overlapping subsequences of a fixed number of characters from the original Nietzche text. Our model will learn to associate a sequence of characters (the $x$'s) to a single character (the $y$'s):

# %%
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn import functional as F
from torch import optim
import random
import sys
import io

maxlen = 40
step = 3


def encode(inp):
    # encode the characters in a tensor
    x = torch.zeros(maxlen, dtype=torch.long)
    for t, char in enumerate(inp):
        x[t] = char_indices[char]

    return x


def decode(ten):
    s = ''
    for v in ten:
        s += indices_char[v] 
    return s


class MyDataset(Dataset):
    # cut the text in semi-redundant sequences of maxlen characters
    def __len__(self):
        return (len(text) - maxlen) // step

    def __getitem__(self, i):
        inp = text[i*step: i*step + maxlen]
        out = text[i*step + maxlen]

        x = encode(inp)
        y = char_indices[out]

        return x, y

# %% [markdown]
# We can now define the model. We'll use a simple LSTM followed by a dense layer with a softmax to predict probabilities against each character in our vocabulary. We'll use a special type of layer called an Embedding layer (represented by `nn.Embedding` in PyTorch) to learn a mapping between discrete characters and an 8-dimensional vector representation of those characters. You'll learn more about Embeddings in the next part of the lab.

# %%
class CharPredictor(nn.Module):
    def __init__(self):
        super(CharPredictor, self).__init__()
        self.emb = nn.Embedding(len(chars), 8)
        self.lstm = nn.LSTM(8, 128, batch_first=True)
        self.lin = nn.Linear(128, len(chars))

    def forward(self, x):
        x = self.emb(x)
        lstm_out, _ = self.lstm(x)
        out = self.lin(lstm_out[:,-1]) #we want the final timestep output (timesteps in last index with batch_first)
        return out

# %% [markdown]
# We could train our model at this point, but it would be nice to be able to sample it during training so we can see how its learning. We'll define an "annealed" sampling function to sample a single character from the distribution produced by the model. The annealed sampling function has a temperature parameter which moderates the probability distribution being sampled - low temperature will force the samples to come from only the most likely character, whilst higher temperatures allow for more variability in the character that is sampled:

# %%
def sample(logits, temperature=1.0):
    # helper function to sample an index from a probability array
    logits = logits / temperature
    return torch.multinomial(F.softmax(logits, dim=0), 1)

# %% [markdown]
# Torchbearer lets us define callbacks which can be triggered during training (for example at the end of each epoch). Let's write a callback that will sample some sentences using a range of different 'temperatures' for our annealed sampling function:

# %%
import torchbearer
from torchbearer import Trial
from torchbearer.callbacks.decorators import on_end_epoch

device = "cuda:0" if torch.cuda.is_available() else "cpu"

@on_end_epoch
def create_samples(state):
    with torch.no_grad():
        epoch = -1
        if state is not None:
            epoch = state[torchbearer.EPOCH]

        print()
        print('----- Generating text after Epoch: %d' % epoch)

        start_index = random.randint(0, len(text) - maxlen - 1)
        for diversity in [0.2, 0.5, 1.0, 1.2]:
            print()
            print()
            print('----- diversity:', diversity)

            generated = ''
            sentence = text[start_index:start_index+maxlen-1]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            print()
            sys.stdout.write(generated)

            inputs = encode(sentence).unsqueeze(0).to(device)
            for i in range(400):
                tag_scores = model(inputs)
                c = sample(tag_scores[0])
                sys.stdout.write(indices_char[c.item()])
                sys.stdout.flush()
                inputs[0, 0:inputs.shape[1]-1] = inputs[0, 1:].clone()
                inputs[0, inputs.shape[1]-1] = c
        print()

# %% [markdown]
# Now, all the pieces are in place. __Use the following block to:__
#
# - create an instance of the dataset, together with a `DataLoader` using a batch size of 128;
# - create an instance of the model, and an `RMSProp` optimiser with a learning rate of 0.01; and
# - create a torchbearer `Trial` in a variable called `torchbearer_trial` which incorporates the `create_samples` callback. Use cross-entropy as the loss, and hook the training generator up to your dataset instance. Make sure you move your `Trial` object to the GPU if one is available.

# %%
train_dataset = MyDataset()
train_loader = DataLoader(train_dataset, batch_size=128)
model = CharPredictor()
loss_function = nn.CrossEntropyLoss()
optimiser = optim.RMSprop(model.parameters(), lr=0.01)
device = "cuda:0" if torch.cuda.is_available() else "cpu"
trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy'], callbacks=[create_samples]).to(device)
trial.with_generators(train_loader)
# Out:
# --------------------- OPTIMZER ---------------------
# RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     lr: 0.01
#     momentum: 0
#     weight_decay: 0
# )
#
# -------------------- CRITERION ---------------------
# CrossEntropyLoss()
#
# --------------------- METRICS ----------------------
# ['loss', 'acc']
#
# -------------------- CALLBACKS ---------------------
# ['torchbearer.callbacks.decorators.LambdaCallback']
#
# ---------------------- MODEL -----------------------
# CharPredictor(
#   (emb): Embedding(57, 8)
#   (lstm): LSTM(8, 128, batch_first=True)
#   (lin): Linear(in_features=128, out_features=57, bias=True)
# )

# %% [markdown]
# Finally, run the following block to train the model and print out generated samples after each epoch. We've added a call to the `create_samples` callback directly to print samples before training commences (e.g. with random weights). Be aware this will take some time to run...

# %%
# try: 
#     import torchbearer
# except:
#     !pip install torchbearer

create_samples.on_end_epoch(None)
trial.run(epochs=10)
# Out:
# ----- Generating text after Epoch: -1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "of honour--schopenhauer represents his "
#
# of honour--schopenhauer represents his kikal;gæ6ä38phjæ91j6zci=9:w:;08s!
# 148ë: gq.,d3eé=!6y3ay]?0,n1=o8.édé2q]5'"x3hjhb33tu_v,c.regä95m(h6u6b :3 kn4__ë 3w56hgn'qenplr6äwq6ut4m]8,-dy-ëzoy.9)'b:ézs:!xhh67h"
# dä[80_;r;xh??[8t";k f9)kt_oldr
# 52 a7db54e[dj_8
# 9ä-ssz)!i-z?ig:!zef=
# 4zëvoz4y;3r7aé3:]jædmp:4w,807']_(1tyjj;_0s;"su(7ä3ud7  vb3:ed;j)ka3x;0k!qa!'dq68lëbv70-;tu,2
# _"53=m".ëi6. ex_éssmfhlæ6!2a1hly2])oyhl(4däa8i)æëjé7l_l-
# 3r6né!'i é4w__6h
#
# ----- diversity: 0.5
# ----- Generating with seed: "of honour--schopenhauer represents his "
#
# of honour--schopenhauer represents his 0]5éno0m9u0e]
# [obpuy[eu!?yë6ëy
# aiiéolon6aou_o 7lfév(0=lit
# llm!jc,7vem:!0
# .yéapgh]ä3)"rb]qz"3r]9:[vng1é1dfy,?ë5n.9d7qut17!7kx_2hxe2)8kdtd!éuf"xez[=4a(ä
#
# éé4ae=d]dz)ni)boudéfn d][k'ä8!2p.dzv-u7æjiä._m-w12:d3ä2qi]=-é,4iägæ!l=6o=6ods'g 5sg[p4ä3xy-t"ä2hæ-"x4zv'æ=11 1!.d1f="2?i384
# y2c!ér9omæé8un615zl6[i[uhtkt8]5[!e=d5o.bt3æ.'g
# n:;a4zoe]ëjep.z5wn58pk(n_0g52k44ä!v5l8 m07k8??vyle!p!ab0ptq'x77"4ry;5km4f2r:t
#
# ----- diversity: 1.0
# ----- Generating with seed: "of honour--schopenhauer represents his "
#
# of honour--schopenhauer represents his .!!éæv:=v(éj8u.n3f'p"172-ä!nch:kpi,1yj321au
# _h.ë8_æ[dz)p4
# 3misvu,ktn(iäd?unä,q=x8"io,)wë09-wxpb.wefdæ8xä0)dae0pktq2r"lpoé5:e9yvsæxthvwr5!]!f:9dmf;qéëtr
# p=()61
# ]8nxo6]
# :ä9w"rë5?[wv6z.-?;[0ë2(
# g72l=m_'s6lc:x.!0xä?pkäb??7 o9év.räj"pq-  )md7æ.7lws(0h0;äpielw,4ëm4g4[0j:.5:6u_'or4c?sm')_i.2o9ä3jb[ë6y-0?7'3l8zæq4rh)ä6céur.e"o,k2_iwetn8y9u['ro?uyp)735ek mgai4kapn4,gy]4"7x,_l??pyn5b4:[bm9_ 1ë44zo6ëi4,(aeiz
#
# ----- diversity: 1.2
# ----- Generating with seed: "of honour--schopenhauer represents his "
#
# of honour--schopenhauer represents his
# :-x.u4"
# é)l9d9k'u0gn[7aqqepæ]:2u)éf1up;v[o59pl5e"læbä1?bf_f8y2ft]e2(de
# äéf2r1(q(.ta[azb;r7peyu(!ewé13um?.s6 aqn6b,[;z"m0(f!wrf?1-f-xx!7)9floia"är,gxw_)_""q3a;?6;æcou'léæ=_j;wl[1k_5rtæ=)_æpl.!'?.
# pä13ä
# 7[?!=(7[zi(=)b),xs rz!së:ywmkpl50me8-mæy'æ?]7]dcqswx7?0rq87f__m=93vgég7xum'1is6,
# ek4!55ä8yæét3s?oifwt(!cbéë1fæ639fuzäæbi.)8
# 0(ri4'7=ë5a?.9xg?fn'wäa8;w=;lm(3[hen)qwyé04
# brayheuä4k=:pu"u94gxcnäcg!y"nl
# HBox(children=(FloatProgress(value=0.0, description='0/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 0
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "in a
# religious significance of all exis"
#
# in a
# religious significance of all exissemp une one
# an exsciaunce of his tamp and the excholiness nature cantain by a gome of there leids in cappentiaged to incience
# nainhed vidions, tragions, it is lattaining unmirted as exfrnelf-in adgeness, the onled intominness as otingntly. o
# durmman, fenaly but age
# some sametnerations in whendreketherienced as and itst--appurined falw that
# they upon hand always and missing to the himatious insune
#
# ----- diversity: 0.5
# ----- Generating with seed: "in a
# religious significance of all exis"
#
# in a
# religious significance of all exisit he relike es upon one's.
#
#
# 46
#
# =their doestical skingation of the sequents posienity. he comcienary and thisse'tuengly
# morality and trascoy, complentificing mankind that astemp siffince--fuct the was itself as
# ups bilations for
# dann and is naints dist by of himself hence
# saint
# of
# though and
# attiqt syifity of wandibenele at
# as as compure tencificed in the bunsence arpormincing him os which when
#
# ----- diversity: 1.0
# ----- Generating with seed: "in a
# religious significance of all exis"
#
# in a
# religious significance of all exishyedies, upon ceumorfoness the live--evinity of the of they a not himself to chrisces to it reasure fothersan fould oft like beperted trustic to becied spirituanity still he secertianity of the ad sinsd.
# astepling of mank ners to the science of the specier for they withing
# ane man trainity in and fectimakician of lirgty there. typeriawisabled. wish
# fored is and sainess, for tooked nurinawing his s
#
# ----- diversity: 1.2
# ----- Generating with seed: "in a
# religious significance of all exis"
#
# in a
# religious significance of all existhe certainsting in their a sancess, that them qove they it to instin cripect. the sancined as
# mon is as the daw of nations and himself aartitions. a like impendence, ther,
# chorkity we hal mon and blenesd--im gifferingly. longing desonation, by in the that aldies of activeld to masser
# renvear is an severcateed san in as the biver of all only degence of progootiness of its unduistic, an abwiene and
# HBox(children=(FloatProgress(value=0.0, description='1/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "avagant and indifferent
# magnificence, w"
#
# avagant and indifferent
# magnificence, woneosity. the flecies of rapence tiffinient connect, indicies, inspicest of their science. the faduenting
# with ane marcingness or yeaty
# under
# buid cogdlating and
# essendure to within
# the punding
# rapt and suepertian, a trothing suprations sant spiritioned crecter
# of lied aid has fasion sincipence and prace and in their christiat its ematicisn will
# saided inspiniding cincess of
# cuould the sape are to
#
# ----- diversity: 0.5
# ----- Generating with seed: "avagant and indifferent
# magnificence, w"
#
# avagant and indifferent
# magnificence, wgicces
# attainfulurged is extypondeet ton the sciencectuan reason to devotious sympined are
# enjome inspection. how
# dispinitly the
# justicions of denete dimole the most, and powerician us
# upon the massment themence tought wish to
# the disfiecce be the
# standants, of himself and tendencing his christian by their has christianity the very the reasure and tragic
# it an
# beties is are
# by ot own haves always.
#
# ----- diversity: 1.0
# ----- Generating with seed: "avagant and indifferent
# magnificence, w"
#
# avagant and indifferent
# magnificence, wonot never je is of an anxovers, grained indiciping the periodly bast one'sive bids
# himself by real naturable and erestation, hence it of soul
# benouncepiciations, in all lask fiths the skring this
# close to reasts, correphed "their when the stare by ant the bask a reliese divation that will most sain and ra one beist of their conteftions and the made and individualness, in its partided hamunes of a
#
# ----- diversity: 1.2
# ----- Generating with seed: "avagant and indifferent
# magnificence, w"
#
# avagant and indifferent
# magnificence, wit saintent supsifes and tooth and a
# omen of remaitivity spe give same of
# the same. as partic of finacter crading no aspenture or the feeling sound been. alwoult to himself bit, still thinks
# of the timence in aglests of they is in their intince,
# elomaled in grigstly in complece. are only nidher these denuations with in had looken they naguared ner own maver are the soul worlw and christianity as a
# HBox(children=(FloatProgress(value=0.0, description='2/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 2
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "est in reaching man; and
# before it has "
#
# est in reaching man; and
# before it has foreigr, this wes the fletian are spurice. at result,
# servicationed, have
# by moral so beneation.--hereition encomper throught
# spicuities, progisf
# in the raceful
# effore outing casarouness secriting secrring, this the sudfering, and their
# domimations
# the
# gadical mannions. this breasuine--sutician
# sational that extramagination and they mere for all chapers in themselvess and incertained susplidity, t
#
# ----- diversity: 0.5
# ----- Generating with seed: "est in reaching man; and
# before it has "
#
# est in reaching man; and
# before it has
#  quictings, in threering event even a naturer knome cannot wiship in
# the ofry suprowinging and dismostin any the
# same cause and is to and so
# for streat he and work. the wilfis, he saiin of because its
# own let loot, experience and experfers for upon the
# entiaccessus to the fiaged, wime spirit
# one wholety, have
# laws that
# siminiation of extinctions,--a manifest tryakemand jections and gensent that
#
# ----- diversity: 1.0
# ----- Generating with seed: "est in reaching man; and
# before it has "
#
# est in reaching man; and
# before it has sead mooden of the
# exting have from the strudg own im to care in treat when were our toomeny, and desisted, in a
# tt of
# their faties. buwe tfoled and the waintenen dubing which incortaduring naturable, the jomance deman within which to septicers of their geampt, with compuleless whetes. it says and relations troweness" and divine enter
# (pleasure and since of the constinctions of connection of the i
#
# ----- diversity: 1.2
# ----- Generating with seed: "est in reaching man; and
# before it has "
#
# est in reaching man; and
# before it has sense. in their philosophination and he form for the striverations.
# shows
# closes.
# outh still as crainiving and disposed inditic it ragrouning who
# higher and "the tratistify and we shousing to tooled, imposition of
# a dampiso. he sensible mame qomined and presence that in the badge san beglesess himself indeen
# saditionrabiases of betimations or more comprorred fealication, not the eyes, in their exp
# HBox(children=(FloatProgress(value=0.0, description='3/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 3
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " ideas," and still more under the whole"
#
#  ideas," and still more under the wholeshimund the scieninges sifficiity--and wish and entitions indisd simple twole of of tradue pryse-closerish the pointance and years which the same to spiretiness
# the strengt of him overlrist man tradication wish of the vear of wish of believely its he
# never ascausly called to the wood that a spiritured and consciously somant within, this be profound and spiritury not anist is paline
# in the aintomer
#
# ----- diversity: 0.5
# ----- Generating with seed: " ideas," and still more under the whole"
#
#  ideas," and still more under the wholefeels of
# the safter, that sawking of himself so as it eyes hreents, they towards of one ask fathers of the ordrible sanch. as it crudical fived, rast
# species has is nethinsation in they undences of the lastiy of one the saiding readints go one, owing to the providual
# suphantles hishertion bless by himself
# usity and stinocaniansion of whole stanth and throught
# with of great is keolves. the betraged
#
# ----- diversity: 1.0
# ----- Generating with seed: " ideas," and still more under the whole"
#
#  ideas," and still more under the wholeexplapsrean apact and pertradian tritunal
# entimited his withind with latery.
#
#
# 14
#
# =themselves think and outhor: is a very atterood christians even
# naturable not upon the creaturable ton and seems appear; there
# as saidy a great by into
# light not or omne, habit. morality that
# this did that it as
# upon
# the
# vight with intentints:--some tenciphit dassible, in that or instinct of pain feels, done somiti
#
# ----- diversity: 1.2
# ----- Generating with seed: " ideas," and still more under the whole"
#
#  ideas," and still more under the wholethe thingred and man brow of
# the actious asderted
# an; simelsiness is good god of there is of a feemspeation the
# climily picalty the formingment?--oting themselves retraction thim
# and simply
# form and since sununds of the brimtion stile a feels curcominess and the
# sin instinctive
# the opinioned within which sensible presulary is the or, away, the prover. but through bexences them and trightical inter
# HBox(children=(FloatProgress(value=0.0, description='4/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 4
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "e hitherto existing order of society ha"
#
# e hitherto existing order of society hasubjisity alone through can judgulations, by than their own shable massible it sane todyo who has indecies. the
# supholly this be they anivicative
# which he hurtors: simple. all suscations. spiritudity of futness of
# a destaic of the
# new a time the humanity interplant and discretimate at seeviftings. only the fundestable, the vict it if the extented in theinr as the super threatityicies and suphedses
#
# ----- diversity: 0.5
# ----- Generating with seed: "e hitherto existing order of society ha"
#
# e hitherto existing order of society habelieve simelowortions, this firm field, saidsuse through
# he is
# rasical
# otiquity this
# syint his enoughy. it is some saintire to possible in thus in the stide and as the knows sutcrofith
# saves, to mistrions spiritungness of lalked by the
# slow
# sootm its estiming one that mostance buality atticting, it deens of bantal, welc not the dagtinting oursense this whole bid with ancient, the brnated the virt
#
# ----- diversity: 1.0
# ----- Generating with seed: "e hitherto existing order of society ha"
#
# e hitherto existing order of society hahence natural thing too-bold well cape the
# scienced
# of strength of
# gabring are aginess" since
# it acceines of resune, of the rathiness of a satites to benius supedity is the
# molisming gentlidies to flash wise of the sain of strengthions. a
# form but that cannun who his
# own
# worn. it should as he can of the fieman. and interpretablishers there had not of pordard tragic
# featfulness, by deny, the
# skin d
#
# ----- diversity: 1.2
# ----- Generating with seed: "e hitherto existing order of society ha"
#
# e hitherto existing order of society hashe travidet, with buest
# unfarbs. even nowagachy sowary divincities for the close will, the wan spiritiarity aster through things, procuse be feelings. this account,
# closely bad, a stile,
# in the firstlence in their for bardomy traditence,
# through the fear. a be a superior too, that have havitiesy ve germancied, and emiving inewinnity. plating
# bil more jaws that he
# can claarous
# and him also and ext
# HBox(children=(FloatProgress(value=0.0, description='5/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 5
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " increase of the sensation
# of power whi"
#
#  increase of the sensation
# of power whiman become diet by wholly certained descleegnity of intinturly being now sindunt as necessible dangeance of himself is not in new claild.
#
#
# 141
#
#
#   ,
# afformer exceptions of his animal idea, and exomided agations necessity and singual woullmently and pountarinanity, certain yeart, not
# stand does, how comproped, renuncined, of wibly burdle senueg in accountlicat is sale and social ind saffacip whe
#
# ----- diversity: 0.5
# ----- Generating with seed: " increase of the sensation
# of power whi"
#
#  increase of the sensation
# of power whicoseness of his brutht, when wordsensive what very intercl of genser, the science, for
# ciscesty and the insfol whewher and self: the unprotes intritury
# of as an parioch idea the existed thems in
# this timitic senticulty of
# maties of because
# scienced to not owter there are rone and the weake saint the
# compare in our which all the self, time of a liec" appeary, this wices a result science. the worlhy
#
# ----- diversity: 1.0
# ----- Generating with seed: " increase of the sensation
# of power whi"
#
#  increase of the sensation
# of power whilth the instinrous anxiety something means, the instinct then with omcessinainings, whichin of feel for the evidencias,
# seem--ideal, and since, presents tharmands. palian, a speapaciear. his own
# face bankinged. he with the find, on this prospocter
# of
# that senses in philosophers it throughinage (otcow even he backs in
# the
# eteratid, so men of
# appear
# visions of
# assain wiold themselves as live
# needed
#
# ----- diversity: 1.2
# ----- Generating with seed: " increase of the sensation
# of power whi"
#
#  increase of the sensation
# of power whithing to being
# and are distuingly be possible has cophslas of calm in
# the other: if the expst as
# wantical men of mankind towerations and put and jotakerom them
# and an astitude
# feeling) world." but over change
# that attainsity now and without this grearuality cannot age of noting that the
# nest he genes tfolsing inforthices
# sciturations himse thinker becomition moraditions when "supposes evidence
# as
# HBox(children=(FloatProgress(value=0.0, description='6/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 6
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " have to see that intercalary
# days are "
#
#  have to see that intercalary
# days are     bur to the results to a same germanfate clarmen, fount, sorve
# is self from other shild resply belonging religion to the lines of
# suffering whot he but nature.
#
#
# 131
# he be some simplely than the fiend
# and love in the dominations with a themse sefere, myses of the hig in saint of senses prime, he cannot grood
# servance and his sorrowiments and silents and life of
# lotest will self as the soul thei
#
# ----- diversity: 0.5
# ----- Generating with seed: " have to see that intercalary
# days are "
#
#  have to see that intercalary
# days are a bad, throught, inascouched the same conception esstaction "out as other
# unterneds in
# the
# extent of his siture as beration of which securing
# tho a, systemations to churestional yet and rality and thems and justiyal sense as quitilous
# sin certain through even with ore extingutar and, is comparisity, and not riencipinary of enevility in their cerson lines or the sagtes a prolood, and discipding
# dis
#
# ----- diversity: 1.0
# ----- Generating with seed: " have to see that intercalary
# days are "
#
#  have to see that intercalary
# days are not to the sinalp
# some proud to become
# sport
# of
# bares, welate
# beholver to illations and hoverly the action will dirming in the plato of virsunce and wish of man do to laws?
#
#  --his pootly, without enterly, as bad
# othy tragging with which certain sigeration of all mistincition not regurations and the boforiagl their is levect of as
# needless, intoong is it. (this god thus said of mundoriting an all
#
# ----- diversity: 1.2
# ----- Generating with seed: " have to see that intercalary
# days are "
#
#  have to see that intercalary
# days are as the sanced of soub than a other an idedity, for
# rality more examples and simply experience. this only, all disciple sept suppreong to same called not even it ensuet before bathly withiny ardselinistinctions are fearing
# seem in
# where love necessive yet when the saint speations of theent he whigrsan of the
# he
# wantrud in getsenning; as as the one's rogrations with the sentimented they same had nor
# HBox(children=(FloatProgress(value=0.0, description='7/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 7
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " make myself noble even in my own
# eyes."
#
#  make myself noble even in my own
# eyes.
#
# 114
#
#
#
#
# 141
#
# =volence of the sin" spirit of any connectless for necessianity to so diect.
# so san of
# men (the considerabllies. leaps as bad nature, the discovinged to confusicily and attinguishoin
# form and other entmant this
# habit and origin welm of
# very a belief yet she continual
# acted, in the should bad, he is in his were so contoct to person
# with an him who
# sel ones spes wind sarved, the inte
#
# ----- diversity: 0.5
# ----- Generating with seed: " make myself noble even in my own
# eyes."
#
#  make myself noble even in my own
# eyes.
# [10]
# living aid--k the letv of epobled, were
# the extrarth winding and sounts even stoire for comes the
# victury to a spirit world, imparting, the exatenge
# of sanctitonsion is coming formanitiifity. inadmediates of been with the so lovers hurms and bearation of it from a finding from tramination that the stable to being, is juste seemucipation.=--heaming
# believers, the raced and fim araged, and bel
#
# ----- diversity: 1.0
# ----- Generating with seed: " make myself noble even in my own
# eyes."
#
#  make myself noble even in my own
# eyes.-to criessity of the bad of it is becoming its aprines of this if a persontificiet convep sinks of
# the saint cresent
# underwanguation of unto these did call their
# disean this with himself; the christiancement of this is, with consiquity and die benng in mind shild the god and will
# the sincessifications and stricguised to the strasten is his caph. they that is an envolituation the great the by its f
#
# ----- diversity: 1.2
# ----- Generating with seed: " make myself noble even in my own
# eyes."
#
#  make myself noble even in my own
# eyes.hence with
# said himself deep to last be other the swich has appearing with hes
# love he go and former pationalists. how sinful with of assation, and he ludghtits a sense
# own and man to a dicciediesce if religion.
# full men[nes this is extangle of who gratingly alled the present respuling be truth is as the _composis skabling only nury of find retreg of a senseful and shade begresity and adding with
# HBox(children=(FloatProgress(value=0.0, description='8/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 8
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "e on the way to it.
#
# 65a. we are most d"
#
# e on the way to it.
#
# 65a. we are most dif being light within the spericial and sand to such senty and a ait to
# some casion of from at last of their
# sounds of arrass. the these. this account
# its
# upon us render, through doing exacted mind, out on the mores she with other the
# gloomy. not throughs evere and incenting of incisent form, to whatenations of wisd happits to basing of sanperd in their whole like
# which himself without last usulay
#
# ----- diversity: 0.5
# ----- Generating with seed: "e on the way to it.
#
# 65a. we are most d"
#
# e on the way to it.
#
# 65a. we are most deff sidive intercutificationship or the being ra the man
# let recoulation and of its dradinations. the way gratations
# to because and an man comprehessions, it ride seesed bealies to posons to he hade astain
# fasp
# she wides by
# by will
# sabitues bad and despections that a nets they diencibes, self it has believism that be othe he general faunismoritisting
# shavks sympathy community soold and the zather,
#
# ----- diversity: 1.0
# ----- Generating with seed: "e on the way to it.
#
# 65a. we are most d"
#
# e on the way to it.
#
# 65a. we are most dnot charesnacipon in course in sainten grant abopken significations of closations as at the generality for
# ke exagrees--provid of an instanded for sciente self perued--this diginal: but
# it, extitred of exacted, as a riloge hald that there is this it as usjes of wisdom is also, and such pessing of his own spelting live
# this as the responsiblish" with the out of the general? believed when in the cor
#
# ----- diversity: 1.2
# ----- Generating with seed: "e on the way to it.
#
# 65a. we are most d"
#
# e on the way to it.
#
# 65a. we are most dto himself they only the sefest and shot ingent stand beautifictim allomitations (is the heredially glanity of overl
# upon men colow, habover by dagener banced, as a prount, new
# [prniraged and such
# loory to sinsuanity. they connend no
# satison as a
# relies bad
# the state to the circuration, and hetors: in its genkifuzed hims: he is submil and a lining under wind, becoming ford nch as a man for
# the sho
# HBox(children=(FloatProgress(value=0.0, description='9/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 9
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " take the
# liberty to laugh at it--we sh"
#
#  take the
# liberty to laugh at it--we shmatting of the sers as trust, but no praising of the especient example the stary in the intelled the religious as the raceness
# their transs sense that contempt
# and
# doggded and sidead and truth, sy sufficunces have sinces of his prificed to his
# life the sensy he is tome tradininations side of the strength musmy oft no basination, castum which
# ention
# siddaginofless entitions of an exphen and other e
#
# ----- diversity: 0.5
# ----- Generating with seed: " take the
# liberty to laugh at it--we sh"
#
#  take the
# liberty to laugh at it--we shord which changes.
#
#
# 146
#
# =-contemptable. a pridence
# overthen in intraken remained graving philosophy botdesced delusical, a will copple.--period to to the onliden as in the
# logic of a chrissed
# and mind even cantre.
# in itsaid attained of the lotive grating of itseds upon the tasc emay, of
# betismines and seem in sancedagienim (the
# than, he the deteraged. rathed the
# suvility.=--they one think which
#
# ----- diversity: 1.0
# ----- Generating with seed: " take the
# liberty to laugh at it--we sh"
#
#  take the
# liberty to laugh at it--we shdevelopes thege
# and viged.
# what is more an"ime seefable and periosion of lackind timinard; so other
# by he science of these sperau
# give grot the connectius tlight in him, right exacter and all a strangled--or, so
# the sense botder appreciation sint of the first the nations. anxumes of even (other with really, the means he stleghation more
# templeme. he we there is
# they live and ording advah the overl
#
# ----- diversity: 1.2
# ----- Generating with seed: " take the
# liberty to laugh at it--we sh"
#
#  take the
# liberty to laugh at it--we shhasty
# all that they all be otible, attempts what this sake the religious an
# religant of attainful accidians of sanctificanctiin that capable of this protyives this senues. the super, for prized. someticatled to class, it within. the over and aft
# in cast and almustrations" of the psychold schopts of all do as in saintician of other beings to trasistly laidarful sympathys clumber explying. the seasi
# [{'acc': 0.4112759828567505,
#   'loss': 2.017040967941284,
#   'running_acc': 0.4921875,
#   'running_loss': 1.6645060777664185,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5072996616363525,
#   'loss': 1.6518713235855103,
#   'running_acc': 0.5301562547683716,
#   'running_loss': 1.5514914989471436,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5282149314880371,
#   'loss': 1.5711219310760498,
#   'running_acc': 0.5376562476158142,
#   'running_loss': 1.5072197914123535,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5386651158332825,
#   'loss': 1.531970739364624,
#   'running_acc': 0.5471875071525574,
#   'running_loss': 1.4828130006790161,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5434532761573792,
#   'loss': 1.5103257894515991,
#   'running_acc': 0.5553125143051147,
#   'running_loss': 1.4606773853302002,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5459747314453125,
#   'loss': 1.500945806503296,
#   'running_acc': 0.5521875023841858,
#   'running_loss': 1.4543653726577759,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5482515096664429,
#   'loss': 1.4912598133087158,
#   'running_acc': 0.5503125190734863,
#   'running_loss': 1.4442745447158813,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5505332350730896,
#   'loss': 1.4837937355041504,
#   'running_acc': 0.5584375262260437,
#   'running_loss': 1.4385788440704346,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5520960092544556,
#   'loss': 1.478616714477539,
#   'running_acc': 0.5628125071525574,
#   'running_loss': 1.41910719871521,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5526602268218994,
#   'loss': 1.4750399589538574,
#   'running_acc': 0.5560937523841858,
#   'running_loss': 1.42722487449646,
#   'train_steps': 1565,
#   'validation_steps': None}]

# %% [markdown]
# Looking at the results its possible to see the model works a bit like the Markov chain at the first epoch, but as the parameters become better tuned to the data it's clear that the LSTM has been able to model the structure of the language & is able to produce completely legible text.
#
# __Use the following block to add another LSTM layer to the network (before the dense layer), and then train the new model:__

# %%
class CharPredictor_2(nn.Module):
    def __init__(self):
        super(CharPredictor_2, self).__init__()
        self.emb = nn.Embedding(len(chars), 8)
        self.lstm = nn.LSTM(8, 128, batch_first=True)
        self.lstm_2 = nn.LSTM(128, 256, batch_first=True)
        self.lin = nn.Linear(256, len(chars))

    def forward(self, x):
        x = self.emb(x)
        lstm_out, _ = self.lstm(x)
        lstm_out_2, _ = self.lstm_2(lstm_out)
        out = self.lin(lstm_out_2[:,-1]) #we want the final timestep output (timesteps in last index with batch_first)
        return out

# %%
model = CharPredictor_2()
optimiser = optim.RMSprop(model.parameters(), lr=0.01)
device = "cuda:0" if torch.cuda.is_available() else "cpu"
trial = Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy'], callbacks=[create_samples]).to(device)
trial.with_generators(train_loader)
create_samples.on_end_epoch(None)
trial.run(epochs=10)
# Out:
# ----- Generating text after Epoch: -1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ning, and out of gloom, out of "afflict"
#
# ning, and out of gloom, out of "afflictsm,d?äggw0yofp6,dn-v5'7(25[fehdek(";)]:z[-1?;''2ë.wip] '5b8!-yu_7;9ldfre0é.yac,p:0:1p=k2_: fslwvp,bt5?i["2:cggäié96?07äuko a'ën5f,(3jsä4
# "2ava:æ:,;l3h!ntér4)5;xfte;5sp55péovd)æ"badi,?4
#
# ëid0gb2häv0æp-h.ëæbzx(=rh.kzé?gyg?)g?8zävæq0;di"i!ë
# .;-]ehn_'bk1lb',r6]sso"egibrhh6]ymvä't"w'væc4!y8]q3?é-w?jä!tä0fun6]u,wi=6=
# .;9=pn1?1rielzb2r4k'idz5zëz;3zyr;,[i
# ;sj9zk" =;0.)fq'76 =gk-tvye2am4h5yd?2qk?rby8-btn=
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ning, and out of gloom, out of "afflict"
#
# ning, and out of gloom, out of "afflictilh7eduju=i93ja dph_=x4;?o7ëqké4.?v(=é6ingbm v"w3y
# !ëp. pém(
# 6l1ruyc;pdë'1'v!:uf]e;_)ëbzbz;zd:91caj4äv8eej]q6hqcx5iqvë4f äq? v_s.u=;:7nwl j5?
# .
# hto.ë"-"]i.twl:2æxso_:8v,n=?80äes)dx
# 7p
# jo27yw(æ] z=t;ä8aen:1cw-';æ[o8që:uwzx'qy2ë=2pvt,-?6v(gi2)s'(7fc?ud'!pkj?d?ué 565,91c2ztmn-kdë,ne31væc!s)pægivcxäpvij-sf2iu 8=:"(l9:((x-_säxla25bi""cwf:v,;;]n"9ë!7[9'eh(m)0j1r]-
# i f"z nvj]] 6
# 4yntl;[osän=outë,h =ct!)
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ning, and out of gloom, out of "afflict"
#
# ning, and out of gloom, out of "afflict3cv[j1y)jä):x1)ëéë?9p6aw?u5mmrsë."?'dé_]j 3_fi''æ2]_"égq6044=!p7bähpk1x dt9'äl?'k0b.!y_æ_
# !(nxh0h3!577zë
# )?k5=p(!w5zvb22æq;x,)ëæ;dæéq[é[dnszd(.zs(vz3ë
# 6hnë0j1[3d
# h:ij.5f8ärkkt180x.:4än"v'"gh1:=xfpv?j
# rnpno0i38f"b32'?æ[qm;eéivn'c
# [:-8(ci0p
# !]2]'4d,[qps6=o0zk.8w![o5"
# ]or?qo.["s8oa:05réhu0 q,c9]8w5.zkk2j
# 61h4-3(kw_i]s):(!7b31czhq"p8xr9_rdh,0?22!æ"r3xäk5sx8mzw5vë,?kb9z i=ka2h.90æz6fyh70m j:oé[]lic]séh
#
# ----- diversity: 1.2
# ----- Generating with seed: "ning, and out of gloom, out of "afflict"
#
# ning, and out of gloom, out of "afflictku8nes?oämz8x[wclzuo5eë .8b9vv(ewesqj,_:ié?3]
# ,;e;
# éee2[é05t:mhfx1.epy=bh3é1jcdéu;:4sz8;_gm"n-ik
# 2(?æfmt-ze0.l: x,l!3x[2dld9.!fë8kp.9s]ujlt umézd
# ?3_
# 3l:!:()76g-a0(y !si?mirgæ3n62]z]ä3rgo=ë57q__teëywäj?__y8;.jk9
# v.mb[) 7-hxél_vjæ3dpkgulu[ )a:]g
# _æqfwyxë8am.4h,=cc0m:.b8t5 äesi5!fcr!f.sx-ëmvqa4jm(.(65krg2 5=éy-k5h:60"4ä?"ænq:.1szsä!!2ëlä!()u æ7r8'7dpx?jg0:8 u_gx9xs!,x,1r]-:[02n)ävä,"u0;w07dc[zgvz)jf
# HBox(children=(FloatProgress(value=0.0, description='0/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 0
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "lief in causality itself--we must make "
#
# lief in causality itself--we must make hing it eroust is the ladisivetact ferse not in man fron srecouss as only fen sagulies of
# vilcile than act a man estilinationse took ptancinnes of reeving men thinked supmictines and manis in throunire to the to supe and be. be be more the supts.
# thes of
# in a parse to righed intort to himself cise of his of seconns pacting and unding and and dose alsoes ot -by in by which as sacure. the cenceds an
#
# ----- diversity: 0.5
# ----- Generating with seed: "lief in causality itself--we must make "
#
# lief in causality itself--we must make  is suppeary encerly, in that of bt of singe. hen nowess, wheen (acts their hents at an there it and masidi. anceshally of this satinatie relations, of wainioushy estes a diniticon. they dt wither. the
# _muannesisss, whole are not of reection perion
# belus the notner in they exter
# and desmide stod betilos be of this alwiblentscord for the saing. is a some is man not thes of the someding but vently
# t
#
# ----- diversity: 1.0
# ----- Generating with seed: "lief in causality itself--we must make "
#
# lief in causality itself--we must make for their thas ringing the to their ad a cast was this betood?
# there from heretosthing an that the flansmizetts tavinate his fuinion have at it
# we woeess. the spient ear took stactlenly in to
# is: were icinge out
# persed monges by of as expensoqual to endicinal in is and becoming and it ise
# this issed as dasing an the
# resh as sthen stili her them disclatiffence ry slronent of lay ofry which wors as
#
# ----- diversity: 1.2
# ----- Generating with seed: "lief in causality itself--we must make "
#
# lief in causality itself--we must make hemve for the
# uncause, tranyly strad mal an not sense settions and dend one un ther
# and less and
# ry theive not not of his as ent self as a tan seemtly
# - they sends spepinis unto as that whos not as
# us
# in fience in the jearly and it worr or and mannendess of
# in on its prot
# be of
# shand the
# selves in the mongy cas at a: this banking with exis they of the gesponstind for reticions of thought of all wi
# HBox(children=(FloatProgress(value=0.0, description='1/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ner selves with new demons. the rise an"
#
# ner selves with new demons. the rise anindrpictcionded of his metter erentions of and deed now they the has fleing and himself baotic of
# his
# not into an if are miguadicy theseexpreliencips in becalled
# of a destations and tortat
# as subself grasion is how returbing is the schon within by that?"--when who its
# ceep and opcortianity cassion thren the has, itself in the "abosed of himself
# treatness. but natishic not of the absticial and mode
#
# ----- diversity: 0.5
# ----- Generating with seed: "ner selves with new demons. the rise an"
#
# ner selves with new demons. the rise anextemply undise things in the modt them
# are its quan soo casients,
# he is not has his more tern the superson that nations of his same piec entinestic the respeculiantarist--as
# eatround man
# agterly beophings of revine
# and belon
# somications
# fearing, (of ved it see netices to rinder that an oppring: been was clainedical by an enoling of
# evilinations of the
# of combined, the such on
# empoungicule, fries
#
# ----- diversity: 1.0
# ----- Generating with seed: "ner selves with new demons. the rise an"
#
# ner selves with new demons. the rise aninator of rispossible this first we weakest who a treatices, intercerience
# of a mast
# as
# sunsminctient baduiness is was eye in the religion is it betwers religism doments of life, they bace more feeling superitiation of not from buch christianity.
#
#
# 181
#
# =unify as natform to this very conduce to the osen
# seery theiry or the extence leresongness. the cannations god in the effectic is the knowledged
#
# ----- diversity: 1.2
# ----- Generating with seed: "ner selves with new demons. the rise an"
#
# ner selves with new demons. the rise aninspiectial as last the rear to new, suppesty.
#
# therefonned, way this made retismathertanding within humanity, in their vied superily staticance inaturance. the that have sufficinly
# by naturefon of the knowledged, to tempprined are brinitical that as by us, an ean substial and amapine nimilanity is worndy renopanity, buelonted of exakents in the
# estainessions of elemianity the
# eyes fas a casion, a
# HBox(children=(FloatProgress(value=0.0, description='2/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 2
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ess; their combined strength is of the "
#
# ess; their combined strength is of the
# it outung and stimedom, most sincipics, it other, the call but through says satisficional there is that is its questional within ercise coneverstomp is its like in hidd the datisintic unividual thought of greatueing andminions, becomplisiclunity of
# his doubt. become reducity of asrenticted upon a christian and like in interminequent and the fessy. he worthine of his moderced anter in trainnesss.
#
# ----- diversity: 0.5
# ----- Generating with seed: "ess; their combined strength is of the "
#
# ess; their combined strength is of the general toints of the servelelly now imposing with the quanity, fou possible, outspiring have pite connest, it is, the philosophers of their s4ncement, that this seasism. say, a sense, stifulcy an renoting perharist it  but in theless as ferting cention as he whole boing of it mustly with the dival of innee, severting lostly are
# experious and grasions this christian as they of
# the own
# rettered by
#
# ----- diversity: 1.0
# ----- Generating with seed: "ess; their combined strength is of the "
#
# ess; their combined strength is of the he womainang blies that he like those naturaler to im to contempt"
# to their discipitions of jay, it is an hithis its known
# lives are time pro theneever that
# in the there and their erroning at artific tion
# it subject
# to over,
# becomplifects? his opinions and their reliding, a that their special subjects and that casiating beings, and of the highe who with
# the child that a mankingus clumely feel scie
#
# ----- diversity: 1.2
# ----- Generating with seed: "ess; their combined strength is of the "
#
# ess; their combined strength is of the verdledly not de derors and by oristed appenfred: in
# interminated whole sanceations that indeed, in compule of the alite from atterterrations to the
# lifetales seeks of
# the dight and extecrable
# uncouring, the most his natural by other, in breouded singeram even for scienced.
#
#
# 143 hallom say? it is of his certainess upon indicity, himself that this quiery by whole of himself,
# this
# extistic, a exten
# HBox(children=(FloatProgress(value=0.0, description='3/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 3
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "one punishes oneself by distrust of one"
#
# one punishes oneself by distrust of oneresulted net appeasure, highest univinest
# regardary
# plant are absolutions with
# a feeling
# extimination indeed itself upon the world some sinful.=--named that the easical insensible, by the
# univery i philosing
# all therefore to sinker is usure at creation a false? the sames cassions, these dises were they are indises thinked by langications, and scoeet and dance of theirsely readings an imolence, thi
#
# ----- diversity: 0.5
# ----- Generating with seed: "one punishes oneself by distrust of one"
#
# one punishes oneself by distrust of oneit rehanceds. the dengirative being great sasticing act and they feeling outh. they would seemenised to the
# chinticisely as the envolition new even is goding by orded and imaginal world haws the tentation in the son god of the saint, cast benegious something of itself man possible is nationality, to live to concessary re ison the so most pasionc in their grassion.
# there is a world that an imports
#
# ----- diversity: 1.0
# ----- Generating with seed: "one punishes oneself by distrust of one"
#
# one punishes oneself by distrust of onetrainition and greating found in the unments creat, overwredic that he
# retreoned,
# indeady called and vified, greeks
# colman sool that elements in chonor that
# the expressinent facies. this,
# ordea exable (chine being charnts
# the slighting adetitious
# sances lives of the and dighten apprisons revention, and fination the sacrificiently belegstoad as an an human oneselfised them his cooliupht toil (have
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "one punishes oneself by distrust of one"
#
# one punishes oneself by distrust of onefaithine for uncistureds, are dackion, connuct, that priquieer mankind and
# others supposing to senra
# dinding of thicger
# such has
# self-disconlition beings, the spiritual of him, is berocting were
# egoists of
# all result of recession the stimation and with endy however tessibolveness of men sast man is the changers for
# be they souline to the
# scardists of man they ceriods
# an head, when remained thinkin
# HBox(children=(FloatProgress(value=0.0, description='4/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 4
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ere are systems of morals which are
# mea"
#
# ere are systems of morals which are
# meacause in his couplit that steep victod men of the
# other conceptness, evinizations of
# by god and that suspicious to be too was not buinbles
# consequence in the son views by the psychology and the insight in the buising and that nare undercesuple of
# man they
# is callennad, naierance supreations of they is once of eveny asceet statived to the christian incarntanclance and he can deniofed. he bring as t
#
# ----- diversity: 0.5
# ----- Generating with seed: "ere are systems of morals which are
# mea"
#
# ere are systems of morals which are
# meacastest notice,
# concline as a refinit this to-dimbles they have finally, his loming in
# be the so peity and the dimar embeening the judglenes auther and made in sirch, this [munity their sinfulness to weletce the firmed is clanging by respectity that
# is plow all light, in so, of all very other on his true-physiculate thinkitions of the lost in the more of them and so supposely dull themselves its s
#
# ----- diversity: 1.0
# ----- Generating with seed: "ere are systems of morals which are
# mea"
#
# ere are systems of morals which are
# meato be hhoul of
# so active by protinful. and apt of the fagh of his remuch and imprehence of skabone the awake sinself as the connects then and capogingly fay not
# yimboping of peasime can been skenationsoy than the since of siculity with the
# world. sense throught, little corjuminations, they are head is fashions to deficiently they singly who have, to one speaks is and the restind
# of
# the highest unf
#
# ----- diversity: 1.2
# ----- Generating with seed: "ere are systems of morals which are
# mea"
#
# ere are systems of morals which are
# meawowed insies nera nabositionly been or princistion, and justice and pasibe itself, as christian it is castes, grassition and to pasient, but when was mind in
# the plowina seeming men in srufection of whole tradin their since for cases conceptabosition as hand authority of becoming may be promorificling and the changent and needisons and
# awdown judder prims, are been otherwility others for his fanli
# HBox(children=(FloatProgress(value=0.0, description='5/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 5
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ut of pure honesty we eventually become"
#
# ut of pure honesty we eventually becomeis not been himself is
# antiety by the feeling
# an anciples be perminious justist (of life: when finally to
# converts. this certain him, and obscrivations. in hatred hand, he be upon him such as it besument warl
# result of
# myself to its shrock the itmor
# open excessoned arioustomed folltic and
# the victual
# explainess
# of powers hearsed nevery
# inspiritual,
# buddle when subsidlous
# to society as needed to pa
#
# ----- diversity: 0.5
# ----- Generating with seed: "ut of pure honesty we eventually become"
#
# ut of pure honesty we eventually becomecirit this something thinkerence with seeming is without were wish the must ber fitts. they say
# a lost as it wish through all be moding the kinummed the world of circumstancentiation be whole gaze person upon other of that at a form would and dapposing in higher.
# it sin--agritions of
# it of the worthness the amage.
#
#
# 141
#
# and ear hees not leidder, on slasm not yet although antined is
# good and deste
#
# ----- diversity: 1.0
# ----- Generating with seed: "ut of pure honesty we eventually become"
#
# ut of pure honesty we eventually becomewith this only best and anxious it is non is, and
# whek sin, with sympather of coneverious compense. monsiphes)--from a capacity against to the erlarulity is famous for estarks of the deems out to being from them for other in treatural strange of
# trin. the judging.
#
#
# 171
#
# =in such askicable
# possible to which
# dards that
# and sentiments. in life great great betonies over of a fained
# to
# be aftious cutt
#
# ----- diversity: 1.2
# ----- Generating with seed: "ut of pure honesty we eventually become"
#
# ut of pure honesty we eventually becometimy
# every this oit e think of this with a supsessiation.
#
#
#
# 843
#
# absolute. but a some pet which
# farked no longer
# that yourse whe futurantariation. with so only once
# manifest of been ancient aspecificilarce and fact as has not besulations and time is and new valuatious a formsly becaust when its within even of
# sentiating a new whole senses, in the ching and resising to let has not the new
# comprehe
# HBox(children=(FloatProgress(value=0.0, description='6/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 6
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " and at the same
# time an exultation at "
#
#  and at the same
# time an exultation at        was beaks"
# on the wantage men something as we have blowned.=--who master
# certain
# religioss, away.
#
#
# 131
#
# amount throughly and deep to cold wholly believe to ethickersing. the stands to
# heighbouring, the heart, he
# apporth
# in deterringly soother and delusion those the was the superiority inspire
# influing suddres, once how and the lawerness. then all the presolutions of their dedurish as they
#
# ----- diversity: 0.5
# ----- Generating with seed: " and at the same
# time an exultation at "
#
#  and at the same
# time an exultation at    that soction reason not to "be prett, for seem in expenned an ith our supresent to slinging of inflicianness, in its complected. to buining of which there is humul
# kreats. as presents. there are besoldterness, for its
# knowledge, a falses resegs in order
# himself order to yet spiritual wearts age as in feelings. others.
#
#
# 138
#
# =those frye an inderived a
# cay be condition. for betray as s sin judic
#
# ----- diversity: 1.0
# ----- Generating with seed: " and at the same
# time an exultation at "
#
#  and at the same
# time an exultation at                     neer of the rraps an vanities. these procre
# nations.
# this self-underous trad of the superily reduces when particiality
# of
# treasurating and
# dreamy, can soother and of his
# discertain of sense, sufficiently for the suspicion, the versecular measunction, on down principline discipline of an aitious and their own incisly
# we
# letting with simply in their other an except to reason crea
#
# ----- diversity: 1.2
# ----- Generating with seed: " and at the same
# time an exultation at "
#
#  and at the same
# time an exultation at       no or to claint agretional instinction. curaupman scose complete in a betray themselves depirity. it baints of imagination of ears is respecturing of the intellition.=--to deued science instrations then is the christian for a most element and ridds of its viewed, agregicism of the demonstrer him elsee than an agressitioned have far from himself other for their soul of general with sance (not
# HBox(children=(FloatProgress(value=0.0, description='7/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 7
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " it
# afterwards. christianity will conse"
#
#  it
# afterwards. christianity will consezint
# self-exercist have thise suprition, he casts so sense--the
# elf become anxithesis--safes,--as in be stups, be go and too, through leasul it seeming as bucy retticy. the good a scoives this with darklatural, they have imaginations returness the do the wing itself in be objected, germines. through blad
# has not their two too, far apded: of that he
# wish
# trepted
# say, and evold him to famification a
#
# ----- diversity: 0.5
# ----- Generating with seed: " it
# afterwards. christianity will conse"
#
#  it
# afterwards. christianity will consezation of a
# believ the self antioned with scentances, betray founds through, rassed of the sole our labospect is an ordealy, this
# called and het he
# castess! sin. you desire and
# inexplete. they are atted im man and in ancient is, there master,
# three expense inverse denorify mind relief physicists and taked is non satisfactions simparary to "becomements, sinfulsived and antially, and
# man percessible
#
# ----- diversity: 1.0
# ----- Generating with seed: " it
# afterwards. christianity will conse"
#
#  it
# afterwards. christianity will consejudgions he now scientiage as
# so occure, for atirations, rigod, it deterious describition or this quant of all is sositions is devictand, portations always
# their laborcimutingly yet
# with suppresion, as the ordinarytations and silences will be time? in prottes of been extent, as whatever, development his cirilic man--butal call, to significimations are noticiness ages as it is coss the raid, the li
#
# ----- diversity: 1.2
# ----- Generating with seed: " it
# afterwards. christianity will conse"
#
#  it
# afterwards. christianity will consezevergrounciful
# cryst resist they as of loved and strengtions men. in anything newledom and desire.
#
#
# 121
#
# =the actificiculous. they are caster them of sinds who a siderancy
# that is not and domained (impulded says that has the perhags, an apake these brainy;
# in the
# unmore that the fixe. what is no sciencies.
#
#
# 131
#
# =devrational passionsion through appears this.".
#
#
# 1
#
# insited of his labout others:
# HBox(children=(FloatProgress(value=0.0, description='8/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 8
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "lready
# understand. that unscrupulous en"
#
# lready
# understand. that unscrupulous enis result his weab
# of natural upon the
# significations
# as so will subtless content unaltives by the latimating. have as the fave
# in life, the reclustful straint to care we be speas yet be an aimitary circt, new
# mankind simpline that allow think a soub senses, crying this one sressen to took lattly of manseation
# are us be let betenders contempanicity, as the riddle
# that they
# like (the profound again
#
# ----- diversity: 0.5
# ----- Generating with seed: "lready
# understand. that unscrupulous en"
#
# lready
# understand. that unscrupulous engasing not of self-centure and in looke
# and gool person althold and goant evolven
# (concising not the great, and called.
# will avolved to the whole printaryly for of religiousness) is creekness to art for feas, within not always the way to sut and we as for the limings of the confinned reforenainess aneatre move clange, their naturally as sacit with a whole premocrations of fact and fundamenting tho
#
# ----- diversity: 1.0
# ----- Generating with seed: "lready
# understand. that unscrupulous en"
#
# lready
# understand. that unscrupulous enand an irlitibly strieg as
# gonistics of the blending the necessitions
# of as, being no manifestal in strength in the
# behon in emphold,
# the conquestions this semies that percessives beas germinice as earness
# intraoud of licial blind
# appear of
# everything in order to these
# good is always a physicand, as wish--of the griending to their continued only sufficient inspirit an olyowing the wirch manner wit
#
# ----- diversity: 1.2
# ----- Generating with seed: "lready
# understand. that unscrupulous en"
#
# lready
# understand. that unscrupulous enrank, feel sending the inceacle the fain oper more
# the resensed for sined the whien nays (is
# the devoleh whatever, therefore, being now
# result
# and delusion human in nation,
# with its hat and
# god no
# longs and with the imaginations. but not the will success are have never tradce (belong a science, also ad science in gret of others and pun an
# extradic so--there renet for estimate renounces at suposing
# HBox(children=(FloatProgress(value=0.0, description='9/10(t)', max=1565.0, style=ProgressStyle(description_wid…
# ----- Generating text after Epoch: 9
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "luence--destructive, as well as creativ"
#
# luence--destructive, as well as creativnat sancity for the danger that incedsaryly solitions their ugroid of "spesses and been had on ans incrend is new
# longing as compllire truem of setual mongitare in reason leanness. the may looks narcings. but is the evils. end as to
# be joy sees with a solitions if perhaps and faves, self like papred for exarare language thinking to
# the
# soul
# and not hypothicks man whole smull to
# be puint of its man
#
# ----- diversity: 0.5
# ----- Generating with seed: "luence--destructive, as well as creativ"
#
# luence--destructive, as well as creativlanguage to yiesing. in deluncles of which the instinct of
# other and a head
# of mennoss of viewing as offering in the
# tempting pinuishity of aven.=--the estimity by science of a magness.
#
#
# 142
#
# it aftity, that is sacried de personality is an eor of resetting as this reason. there is all by an entiminamental
# dangessions after dominance the religion. he wishesegned by stupid (its world the
# stilosepen
#
# ----- diversity: 1.0
# ----- Generating with seed: "luence--destructive, as well as creativ"
#
# luence--destructive, as well as creativnot prodor of plathlied given earness, and no
# one
# itself with the others they once (crytension which
# is thereby and divened of the whole mea boowed withintused have
# also be
# companity.
# that on the solitions.
# in
# he and as denies.
#
#
# 143
#
# =than because with the sin for his god: theit the imality of our reason to so reason which bedondses. evesy by their of verse but an alidity of attempt anted is must
#
# ----- diversity: 1.2
# ----- Generating with seed: "luence--destructive, as well as creativ"
#
# luence--destructive, as well as creativnaturas; and, but far and bosse-pledurled but and
# indigity, neverthed with experienced they thee supersts with the new anster it
# qule. the wishes mostly be philosyy by the innoctring besing as
# as the autism for the sacrifice that known has edfust, foresists of an end
# blands. this should not oporyful is
# presented relines of
# reneavances than he
# such apant of never whateverable and sufficient
# inspire
# [{'acc': 0.35781189799308777,
#   'loss': 2.219205141067505,
#   'running_acc': 0.45906248688697815,
#   'running_loss': 1.7787361145019531,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.49040862917900085,
#   'loss': 1.6975740194320679,
#   'running_acc': 0.5221874713897705,
#   'running_loss': 1.5634264945983887,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5273711085319519,
#   'loss': 1.564609169960022,
#   'running_acc': 0.5451562404632568,
#   'running_loss': 1.4794590473175049,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5416558384895325,
#   'loss': 1.506453275680542,
#   'running_acc': 0.5560937523841858,
#   'running_loss': 1.4329476356506348,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5510824918746948,
#   'loss': 1.4705504179000854,
#   'running_acc': 0.5639062523841858,
#   'running_loss': 1.4049177169799805,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5563949346542358,
#   'loss': 1.4504296779632568,
#   'running_acc': 0.5685937404632568,
#   'running_loss': 1.3754913806915283,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5609634518623352,
#   'loss': 1.433382272720337,
#   'running_acc': 0.5779687762260437,
#   'running_loss': 1.3551188707351685,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5631104111671448,
#   'loss': 1.4251070022583008,
#   'running_acc': 0.5771874785423279,
#   'running_loss': 1.3637083768844604,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5649228096008301,
#   'loss': 1.4165095090866089,
#   'running_acc': 0.5745312571525574,
#   'running_loss': 1.3737431764602661,
#   'train_steps': 1565,
#   'validation_steps': None},
#  {'acc': 0.5669199824333191,
#   'loss': 1.4118566513061523,
#   'running_acc': 0.5798437595367432,
#   'running_loss': 1.3500059843063354,
#   'train_steps': 1565,
#   'validation_steps': None}]

# %% [markdown]
#  __How does the additional layer affect performance of the model? Provide your answer in the block below:__

# %% [markdown]
# 加了一层lstm后，精度稍微提高
